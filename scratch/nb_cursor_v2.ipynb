# %%
import httpx
import pprint as pp
import base64
import json
from pprint import pprint
from refund_lab.client import decode_cursor
from refund_lab.utils import b64decode_relaxed

PORT = "8088"
API_URL = "http://127.0.0.1:" + PORT
DEV_TOKEN = "rl_live_8f2c1d94e6b74a03"


def auth_to_API(client: httpx.Client):
    resp = client.post(API_URL + "/v1/auth/token",
                   headers={"Authorization": f"Bearer {DEV_TOKEN}"})
    live_token = resp.json()["access_token"]
    client.headers["Authorization"] = f"Bearer {live_token}"

def byte_decode(cursor) -> dict | None:
    return json.loads(b64decode_relaxed(cursor))

# %%
client = httpx.Client(base_url=API_URL, timeout=10,
                      mounts={"all://localhost": None,
                              "all://127.0.0.1": None})
auth_to_API(client)

as_of = "2027-01-31T00:00:00"
since = "2026-01-15T00:00:00"
until = "2026-01-25T00:00:00"

response = client.get(API_URL + "/v1/orders",
                     params={"limit":50,
                             "as_of":as_of,
                             "since":since,
                             "until":until})
cursor = response.json()["cursor"]
next_cursor = response.json()["next_cursor"]

# %%
pprint(decode_cursor(cursor))
pprint(decode_cursor(next_cursor))
# Out:
# None
# {'as_of': '2026-05-21T05:01:48',
#  'entity': 'orders',
#  'last_seen_value': '2026-01-16T14:57:56',
#  'prev_last_seen_value': None,
#  'prev_rows_served': None,
#  'rows_served': 371,
#  'since': '2026-01-15T00:00:00',
#  'total_count': 305,
#  'until': '2026-01-25T00:00:00'}

# %%
cursor = next_cursor

# %%
response = client.get(API_URL + "/v1/orders",
                     params={"limit":50, "cursor": cursor})
cursor = response.json()["cursor"]
next_cursor = response.json()["next_cursor"]

# %%
pprint(decode_cursor(cursor))
pprint(decode_cursor(next_cursor))
# Out:
# {'as_of': '2026-05-21T05:01:48',
#  'entity': 'orders',
#  'last_seen_value': '2026-01-16T14:57:56',
#  'prev_last_seen_value': None,
#  'prev_rows_served': None,
#  'rows_served': 371,
#  'since': '2026-01-15T00:00:00',
#  'total_count': 305,
#  'until': '2026-01-25T00:00:00'}
# {'as_of': '2026-05-21T05:01:48',
#  'entity': 'orders',
#  'last_seen_value': '2026-01-18T09:44:02',
#  'prev_last_seen_value': '2026-01-16T14:57:56',
#  'prev_rows_served': 371,
#  'rows_served': 421,
#  'since': '2026-01-15T00:00:00',
#  'total_count': 305,
#  'until': '2026-01-25T00:00:00'}

# %%
response = client.get(API_URL + "/v1/orders",
                     params={"limit":50})
cursor = response.json()["cursor"]
next_cursor = response.json()["next_cursor"]
pprint(decode_cursor(cursor))
pprint(decode_cursor(next_cursor))
# Out:
# None
# {'as_of': '2026-05-21T05:02:50',
#  'entity': 'orders',
#  'last_seen_value': '2026-01-03T16:56:56',
#  'prev_last_seen_value': None,
#  'prev_rows_served': None,
#  'rows_served': 50,
#  'since': None,
#  'total_count': 4643,
#  'until': None}

# %%
response = client.get(API_URL + "/v1/orders",
                     params={"limit":50, "until":"2026-01-10T10:00:00"})
cursor = response.json()["cursor"]
next_cursor = response.json()["next_cursor"]
pprint(decode_cursor(cursor))
pprint(decode_cursor(next_cursor))
# Out:
# None
# {'as_of': '2026-05-21T05:37:16',
#  'entity': 'orders',
#  'last_seen_value': '2026-01-03T16:56:56',
#  'prev_last_seen_value': None,
#  'prev_rows_served': None,
#  'rows_served': 50,
#  'since': None,
#  'total_count': 202,
#  'until': '2026-01-10T10:00:00'}
