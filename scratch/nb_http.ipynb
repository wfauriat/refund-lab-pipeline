# %%
import httpx
import pprint

PORT = "8088"
API_URL = "http://127.0.0.1:" + PORT

dev_token = "rl_live_8f2c1d94e6b74a03"
token = "void"

# %%
# call with the context manager
with httpx.Client(base_url=API_URL, timeout=10) as client:
    resp = client.get(API_URL + "/v1/orders",
                        params={"limit":5},
                        headers={"Authorization": f"Bearer {token}"})
    print(resp.status_code)
    if resp.status_code == 401:
        resp = client.post(API_URL + "/v1/auth/token",
                        headers={"Authorization": f"Bearer {dev_token}"})
        token = resp.json()["access_token"]
        client.headers["Authorization"] = f"Bearer {token}"
        resp = client.get(API_URL + "/v1/orders",
                params={"limit":5})
    if resp.status_code == 200:
        pprint.pprint(resp.json()["data"][0])
# Out:
# 200
# {'channel': 'web',
#  'customer_id': '0004968',
#  'items': [{'category': 'outdoor',
#             'qty': 3,
#             'sku': 'OUT-5027',
#             'unit_price_cents': 4074},
#            {'category': 'beauty',
#             'qty': 1,
#             'sku': 'BEA-1698',
#             'unit_price_cents': 4059},
#            {'category': 'apparel',
#             'qty': 1,
#             'sku': 'APP-4542',
#             'unit_price_cents': 4987}],
#  'knowledge_time': '2026-01-01T04:45:17',
#  'occurred_at': '2026-01-01T04:42:36',
#  'order_id': 'ORD-00000001',
#  'order_total_cents': 21268,
#  'payment_method': 'card',
#  'shipping_speed': 'standard',
#  'version': 1}
